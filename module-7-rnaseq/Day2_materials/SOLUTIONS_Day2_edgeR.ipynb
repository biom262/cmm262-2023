# %% [markdown]
# ## edgeR-TMM normalization with miRNA counts table

# %% [markdown]
# https://www.bioconductor.org/packages/release/bioc/vignettes/edgeR/inst/doc/edgeRUsersGuide.pdf

# %%
options(stringsAsFactors = FALSE)

# %% [markdown]
# Load required libraries (install packages if required)

# %%
#Load packages
library(limma)
library(edgeR)
library(data.table)
library(RColorBrewer)
library(gplots)
# Out:
# Attaching package: ‘gplots’
#
#
# The following object is masked from ‘package:stats’:
#
#     lowess

# %% [markdown]
# ### Creating DGE object for edgeR

# %% [markdown]
# Read in counts file `data/Serum_ExoR_Nor_miRNA_counts.csv` and view head of file

# %%
#Read file
counts <- read.csv("data/Serum_ExoR_Nor_miRNA_counts.csv", stringsAsFactors=F, row.names=1)
head(counts)
# Out:
#                ExoRNeasy1_1 ExoRNeasy2_2 ExoRNeasy3_3 ExoRNeasy1_145 Nor1
# hsa-miR-122-5p   2160         3274         3310        1986          95981
# hsa-miR-486-5p  27142        39637        49572       26038          44072
# hsa-miR-92a-3p  31034        46010        56577       18258          44786
# hsa-miR-21-5p  143470       266112       277497       82365          88485
# hsa-miR-423-5p  32979        51863        65891       28585          30736
# hsa-let-7b-5p   60058        78710       112326       46062          41143
#                Nor2  Nor3
# hsa-miR-122-5p 85210 358012
# hsa-miR-486-5p 40849 163263
# hsa-miR-92a-3p 30294  71414
# hsa-miR-21-5p  83749 145037
# hsa-miR-423-5p 33077 103540
# hsa-let-7b-5p  49977  55042

# %% [markdown]
# Define groups and design and create `dge` using `DGEList()`.

# %%
group<-as.factor(c("ExoR","ExoR","ExoR","ExoR","Nor","Nor","Nor"))
group

design <- model.matrix(~0+group)
design

dge<- DGEList(counts=counts,group=group)
# Out:
# [1] ExoR ExoR ExoR ExoR Nor  Nor  Nor
# Levels: ExoR Nor
#   groupExoR groupNor
# 1 1         0
# 2 1         0
# 3 1         0
# 4 1         0
# 5 0         1
# 6 0         1
# 7 0         1

# %% [markdown]
# Plot library sizes

# %%
par(mar=c(10,5,5,5))
options(scipen=5)
barplot(dge$samples$lib.size, horiz=F, names.arg=colnames(dge$counts), las=2, cex.name = 0.5, cex.axis=.5, 
        main="Library Size")
# Out:
# Plot with title “Library Size”

# %%
#To check
class(dge)
dim(dge)
dge$samples
# Out:
# [1] "DGEList"
# attr(,"package")
# [1] "edgeR"
# [1] 1826    7
#                group lib.size norm.factors
# ExoRNeasy1_1   ExoR   896744  1
# ExoRNeasy2_2   ExoR  1452574  1
# ExoRNeasy3_3   ExoR  1626310  1
# ExoRNeasy1_145 ExoR   574327  1
# Nor1           Nor    823880  1
# Nor2           Nor    742767  1
# Nor3           Nor   2075355  1

# %% [markdown]
# ### Filtering based on cpm cutoff
#
# Filter miRNAs with at least 12 cpm present in at least 2 samples

# %%
table(rowSums(dge$counts==0)==7)
keep <- rowSums(cpm(dge)>12) >= 2
dge.f <- dge[keep, , keep.lib.sizes=FALSE]
dim(dge.f)
# Out:
# FALSE  TRUE
#   809  1017
# [1] 419   7

# %% [markdown]
# ### Estimate dispersion
# Estimate dispersion: The square root of the common dispersion gives the coefficient of variation of biological variation.
#
# Generate the estimate dispersion `d` with `estimateDisp()` using the filtered dge (`dge.f`).

# %%
#estimate dispersions
d <- estimateDisp(dge.f, design=design)

# %% [markdown]
# Here the common dispersion is found to be 0.92, so the coefficient of biological variation (BCV) is around 0.96.

# %%
d$common.dispersion
sqrt(d$common.disp)
# Out:
# [1] 0.9218521
# [1] 0.9601313

# %% [markdown]
# ### Normalization using TMM
# “TMM (weighted trimmed mean of log expression) determines scaling factor calculated after double trimming values at the two extremes based on log-intensity ratios (M-values) and log-intensity averages (A-values)” (Dillies et al. Briefings in Bioinformatics, Vol. 14 (6): 671–683, 2013)
#
# To normalize using TMM,
# - Calculate the normalization factors (`calcNormFactors()`) using `d`
# - Maximize the negative binomial conditional common likelihood to estimate a common dispersion value across all genes (`estimateCommonDisp()`)
# - Compute genewise exact tests for differences in the means between two groups of negative-binomially distributed counts (`exactTest()`)

# %%
TMM <- calcNormFactors(d, method="TMM")
TMM <- estimateCommonDisp(TMM)
TMM <- exactTest(TMM)
table(p.adjust(TMM$table$PValue, method="BH")<0.05)
TMM.table<-data.frame(topTags(TMM,n=61))
write.table(TMM.table,file="expected_output/edgeR_TMM_p0.05.txt",sep="\t")
# Out:
# FALSE  TRUE
#   358    61

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Raw and unfiltered data

# %% [markdown]
# First calculate cpm and log cpm using the unfiltered data (`dge`)

# %%
# Raw data
cpm <- cpm(dge)
lcpm <- cpm(dge, log=TRUE)

# %% [markdown]
# Now calculate the log cpm for the filtered data (`dge.f`)

# %%
# Filtered data
lcpm.f <- cpm(dge.f, log=TRUE)

# %% [markdown]
# Lastly calculated the TMM normalized data using `dge.f` and get the log cpm of the normalized data (`dge.norm`).

# %%
# TMM normalized data
dge.norm <- calcNormFactors(dge.f,method="TMM") 
dge.norm$samples$norm.factors
lcpm.norm <- cpm(dge.norm, log=TRUE)
# Out:
# [1] 1.0113710 1.0049834 0.9919675 1.0690993 0.9809371 1.0490079 0.9015612

# %%
#set colours for graphs
nsamples <- ncol(dge)
nsamples<-(dge.f)
nsamples<-ncol(dge.norm)
col <- brewer.pal(nsamples, "Paired")

#Visualise filtered vs unfiltered data
par(mfrow=c(1,2))

#plot unfiltered data
samplenames<-c("ExoR1","ExoR2","ExoR3","ExoR4","Nor1","Nor2","Nor3")

plot(density(lcpm[,1]),col=col(lcpm,as.factor = FALSE),lwd=1,ylim=c(0,2.5),las=2,main="",xlab="")

title(main="A. Raw data", xlab="Log-cpm")
abline(v=0, lty=3)
for (i in 2:nsamples){
  den <- density(lcpm[,i])
  lines(den$x, den$y, col=col[i], lwd=2)
}
legend("topright", samplenames, text.col=col, bty="n",cex=0.8,pt.cex=0.8)


#plot filtered data
plot(density(lcpm.f[,1]), col=col(lcpm.f,as.factor=FALSE), lwd=2, ylim=c(0,0.5), las=2,
     main="", xlab="")

title(main="B. Filtered data", xlab="Log-cpm")
abline(v=0, lty=3)
for (i in 2:nsamples){
  den <- density(lcpm.f[,i])
  lines(den$x, den$y, col=col[i], lwd=2)
}
legend("topright", samplenames, text.col=col, bty="n",cex=0.8,pt.cex=0.8)
# Out:
# Plot with title “B. Filtered data”

# %% [markdown]
# ### Boxplots of TMM-Normalized vs. unnormalized data

# %%
# Unnormalized data
lcpm <- cpm(dge, log=TRUE)

# %%
# TMM normalized data
dge.norm <- calcNormFactors(dge.f,method="TMM") 
dge.norm$samples$norm.factors
lcpm.norm <- cpm(dge.norm, log=TRUE)
# Out:
# [1] 1.0113710 1.0049834 0.9919675 1.0690993 0.9809371 1.0490079 0.9015612

# %%
par(mfrow=c(1,2))

# Unnormalised data
boxplot(lcpm,las=2, col=col, main="",ylim=c(2,20),names=c("ExoR1","ExoR2","ExoR3","ExoR4","Nor1","Nor2","Nor3"))
title(main="A. Unnormalized data",ylab="Log-cpm")

# TMM normalized data
boxplot(lcpm.norm, las=2, col=col, main="", ylim=c(2,20),
        names=c("ExoR1","ExoR2","ExoR3","ExoR4","Nor1","Nor2","Nor3"))

title(main="B. TMM Normalized data",ylab="Log-cpm")
# Out:
# Plot with title “B. TMM Normalized data”

# %% [markdown]
# ### PCA plot
# Make a PCA plot using the log cpm normalized data (`lcpm.norm`)

# %%
#MDS plot PCA
par(mfrow=c(1,2))
col.group <- group
levels(col.group) <- brewer.pal(nlevels(col.group), "Set1")
col.group <- as.character(col.group)
plotMDS(lcpm.norm, labels=group, col=col.group)
title(main="Sample groups")
# Out:
# Warning message in brewer.pal(nlevels(col.group), "Set1"):
# “minimal value for n is 3, returning requested palette with 3 different levels
# ”
# Plot with title “Sample groups”

# %% [markdown]
# ### Heatmap of miRNAs significantly different between groups

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p><b>Exercise:</b> Generate the heatmap for significantly different miRNAs</p>
# </div>
#
# Hint: First subset the miRNAs in the log cpm TMM-normalized data (`lcpm.norm`) using the miRNAs in the `TMM.table`

# %%
# subset miRNAs from lcpm normalized data
miRNAs<-as.list(row.names(TMM.table))
miRNAs_lcpm.norm<-subset(lcpm.norm,rownames(lcpm.norm) %in% miRNAs)

# %%
## Get some nicer colours
mypalette <- brewer.pal(11,"RdYlBu")
morecols <- colorRampPalette(mypalette)
# Set up colour vector for celltype variable
col.cell <- c("purple","orange")[group]

heatmap.2(miRNAs_lcpm.norm,col=rev(morecols(50)),trace="none", main="p<0.05 TMM normalized",
          ColSideColors=col.cell,scale="row",margins=c(9,9), cexCol=0.8)
# Out:
# Plot with title “Color Key
# and Histogram”
